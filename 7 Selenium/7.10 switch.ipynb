# %%
#Basado en https://www.udemy.com/course/big-data-data-science-python-web-scraping-2019-achirou-alvaro-chirou/learn/lecture/21322330#notes

from selenium.webdriver.common.keys import Keys
from selenium import webdriver
import unittest
import time

chrome_driver = webdriver.Chrome("chromedriver.exe")
driver = chrome_driver
driver.get("https://www.w3schools.com/howto/howto_css_switch.asp")
time.sleep(2)


switch = driver.find_element_by_xpath("//*[@id='main']/label[3]/div")
switch.click()
time.sleep(2)
switch.click()
time.sleep(2)

#driver.close()

# %%
from IPython.display import Image
Image("7.10.JPG")
