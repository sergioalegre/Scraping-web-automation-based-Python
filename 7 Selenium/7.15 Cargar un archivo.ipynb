# %%
#Basado https://www.udemy.com/course/big-data-data-science-python-web-scraping-2019-achirou-alvaro-chirou/learn/lecture/21434460#notes

from selenium.webdriver.common.by import By
from selenium import webdriver
import time

cargar = webdriver.Chrome("chromedriver.exe")
cargar.get("https://mdbootstrap.com/plugins/jquery/file-upload/")
time.sleep(2)

#el id del campo input
cargar.find_element_by_id("input-file-now").send_keys("C:\\Users\\sergio\\Desktop\\foto perfil\\Screenshot_2.png")

# %%
from IPython.display import Image
Image("7.15.JPG")
